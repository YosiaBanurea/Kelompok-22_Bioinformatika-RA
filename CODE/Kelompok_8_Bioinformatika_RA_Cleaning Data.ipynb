# %% [markdown]
# ## **`Mengunduh Library yang dibutuhkan`**
# > Library yang digunakan akan diunduh

# %%
# !pip install rd

# %% [markdown]
# ## **`Library`**
# > Pustaka python yang digunakan dalam percobaan ini

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **`Dataset`**
# > Mengupload dataset yang akan digunakan

# %%
raw_data = pd.read_csv('/content/NLRP3.csv')
done_data = pd.read_csv('/content/NLRP3_done.csv')

# %% [markdown]
# ## **`Data Understanding`**
# > Melihat pola data dan pemilihan fitur

# %%
raw_data.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0         NaN           Active      5539969                  []
# 1         NaN           Active      5539970                  []
# 2         NaN           Active      5539971                  []
# 3         NaN           Active      5539972                  []
# 4         NaN         inactive      5539973                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL1737963  PUBCHEM_BIOASSAY: Dose Response confirmation o...
# 1   CHEMBL1737963  PUBCHEM_BIOASSAY: Dose Response confirmation o...
# 2   CHEMBL1737963  PUBCHEM_BIOASSAY: Dose Response confirmation o...
# 3   CHEMBL1737963  PUBCHEM_BIOASSAY: Dose Response confirmation o...
# 4   CHEMBL1737963  PUBCHEM_BIOASSAY: Dose Response confirmation o...
#
#   assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0          F                      NaN                     NaN  BAO_0000190
# ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843 entries, 0 to 842
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   action_type                461 non-null    object
#  1   activity_comment           138 non-null    object
#  2   activity_id                843 non-null    int64
#  3   activity_properties        843 non-null    object
#  4   assay_chembl_id            843 non-null    object
#  5   assay_description          843 non-null    object
#  6   assay_type                 843 non-null    object
#  7   assay_variant_accession    0 non-null      float64
#  8   assay_variant_mutation     0 non-null      float64
#  9   bao_endpoint               843 non-null    object
#  10  bao_format                 843 non-null    object
#  11  bao_label                  843 non-null    object
#  12  canonical_smiles           843 non-null    object
# ...

# %%
def unique_data(data, columns):
  print("\n")
  print(columns)
  print("="*50)
  list_data = data[columns]
  return list_data.unique()

# %%
for i in raw_data.columns:
  print(unique_data(raw_data, i))
# Out:
# action_type
# ...
# [nan
#  "{'action_type': 'INHIBITOR', 'description': 'Negatively effects (inhibits) the normal functioning of the protein e.g., prevention of enzymatic reaction or activation of downstream pathway', 'parent_type': 'NEGATIVE MODULATOR'}"
#  "{'action_type': 'ANTAGONIST', 'description': 'Binds to a receptor and prevents activation by an agonist through competing for the binding site', 'parent_type': 'NEGATIVE MODULATOR'}"]
#
#
# activity_comment
# ...
# ['Active' 'inactive' nan 'Nd(Insoluble)']
#
#
# activity_id
# ...
# [ 5539969  5539970  5539971  5539972  5539973  5539974  5539975  5539976
#   5539977  5539978  5539979  5539980  5539981  5539982  5539983  5539984
#   5539985  5539986  5539987  5539988  5539989  5539990  5539991  5539992
#   5539993  5539994  5539995  5539996  5539997  5539998  5539999  5540000
#   5540001  5540002  5540003  5540004  5540005  5540006  5540007  5540008
#   5540009  5540010  5540011  5540012  5540013  5540014  5540015  5540016
# ...

# %%
print(f"Banyaknya fitur dalam dataset : {len(raw_data.columns)} fitur")
# Out:
# Banyaknya fitur dalam dataset : 46 fitur

# %%
print(f"Banyaknya baris data : {len(raw_data)} baris")
# Out:
# Banyaknya baris data : 843 baris

# %%
print("List Kolom Fitur didalam Data")
print("#"*50)
print([raw_data.columns])
# Out:
# List Kolom Fitur didalam Data
# ##################################################
# [Index(['action_type', 'activity_comment', 'activity_id', 'activity_properties',
#        'assay_chembl_id', 'assay_description', 'assay_type',
#        'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint',
#        'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment',
#        'data_validity_description', 'document_chembl_id', 'document_journal',
#        'document_year', 'ligand_efficiency', 'molecule_chembl_id',
#        'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id',
#        'standard_flag', 'standard_relation', 'standard_text_value',
#        'standard_type', 'standard_units', 'standard_upper_value',
#        'standard_value', 'target_chembl_id', 'target_organism',
#        'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type',
# ...

# %% [markdown]
# ## **`Pre-processing Data`**
# > Proses pemilihan data berdasarkan fitur yang tersedia didalam data

# %%
df = raw_data.copy()
df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0         NaN           Active      5539969                  []
# 1         NaN           Active      5539970                  []
# 2         NaN           Active      5539971                  []
# 3         NaN           Active      5539972                  []
# 4         NaN         inactive      5539973                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL1737963  PUBCHEM_BIOASSAY: Dose Response confirmation o...
# 1   CHEMBL1737963  PUBCHEM_BIOASSAY: Dose Response confirmation o...
# 2   CHEMBL1737963  PUBCHEM_BIOASSAY: Dose Response confirmation o...
# 3   CHEMBL1737963  PUBCHEM_BIOASSAY: Dose Response confirmation o...
# 4   CHEMBL1737963  PUBCHEM_BIOASSAY: Dose Response confirmation o...
#
#   assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0          F                      NaN                     NaN  BAO_0000190
# ...

# %%
# Memilih fitur
df = df[["molecule_chembl_id",
         "canonical_smiles",
         "bao_format",
         "assay_type",
         "activity_comment",
         "pchembl_value",
         "potential_duplicate"]]

# Dataset (fix)
df.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL1336269                      COc1ccc(NC(=O)C#Cc2ccccc2)cc1
# 1        CHEMBL16312                    COc1ccc(-c2cc(=O)c3ccccc3o2)cc1
# 2      CHEMBL1596681               Br.CCCCCCCCCn1c2c(c(=N)c3c1CCC3)CCC2
# 3      CHEMBL1447078                      CCCC1CCC(c2ccc(OCC)cc2)=CC1=O
# 4      CHEMBL1531200  Cc1nc2ccc(Nc3nc4cc(S(=O)(=O)N5CCOCC5)ccc4o3)cc2s1
#
#     bao_format assay_type activity_comment  pchembl_value  potential_duplicate
# 0  BAO_0000019          F           Active           5.10                    0
# 1  BAO_0000019          F           Active           4.51                    0
# 2  BAO_0000019          F           Active           5.04                    0
# 3  BAO_0000019          F           Active           4.27                    0
# 4  BAO_0000019          F         inactive            NaN                    0

# %%
df.to_csv("Dataset_Clean.csv", index=False)
